# %% [markdown]
# <a href="https://colab.research.google.com/github/Pranav-Trivedi20/Algorithms-and-Problem-Solving-Lab/blob/main/Lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Shortest Path Using Dijkstra Algorithm in Python
# Problem Description:
# Given a weighted graph with non negative edge weights. Find the shortest distance from a source vertex to all other vertices using Dijkstra algorithm

# %% [markdown]
# #Theory
# Dijkstra algorithm finds shortest distance from one source node to all other nodes in a weighted graph with non negative weights. Dictionary structure stores nodes as keys and neighbor nodes with weights as values.
#
# ##Algorithm Steps
#
# 1. Represent graph using dictionary.
# 2. Set distance of every node as infinity.
# 3. Set distance of source node as 0.
# 4. Select node with smallest distance among unvisited nodes.
# 5. Update distance of neighbor nodes.
# 6. Repeat until all nodes get visited.

# %%
def dijkstra(graph, start):

    distances = {}
    visited = []

    for node in graph:
        distances[node] = float('inf')

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance

    return distances

# %%
graph = {
'A': {'B': 4, 'C': 2},
'B': {'A': 4, 'C': 5, 'D': 10},
'C': {'A': 2, 'B': 5, 'D': 3},
'D': {'B': 10, 'C': 3}

}

result = dijkstra(graph, 'A')

for node in result:
    print("Distance from A to", node, "=", result[node])
# Out:
# Distance from A to A = 0
# Distance from A to B = 4
# Distance from A to C = 2
# Distance from A to D = 5

# %% [markdown]
# Now, let's implement
# 1. Modify program for user input graph using dictionary.
# 2. Display shortest path with total distance.
# 3. Add two more nodes in graph.
# 4. Test algorithm with different source nodes.

# %%
graph = {}

n = int(input("Enter number of nodes: "))

for i in range(n):
    node = input(f"\nEnter node {i+1}: ")
    graph[node] = {}

    edges = int(input(f"Enter number of neighbors for {node}: "))

    for j in range(edges):
        neighbor = input("  Enter neighbor: ")
        weight = int(input("  Enter weight: "))
        graph[node][neighbor] = weight
# Out:
# Enter number of nodes: 3
#
# Enter node 1: A
# Enter number of neighbors for A: 2
#   Enter neighbor: B
#   Enter weight: 4
#   Enter neighbor: C
#   Enter weight: 2
#
# Enter node 2: B
# Enter number of neighbors for B: 1
#   Enter neighbor: C
#   Enter weight: 5
#
# Enter node 3: C
# Enter number of neighbors for C: 0

# %%
def dijkstra_with_path(graph, start):

    distances = {}
    visited = []
    previous = {}

    for node in graph:
        distances[node] = float('inf')
        previous[node] = None

    distances[start] = 0

    while len(visited) < len(graph):

        min_node = None
        min_distance = float('inf')

        for node in graph:
            if node not in visited and distances[node] < min_distance:
                min_distance = distances[node]
                min_node = node

        visited.append(min_node)

        for neighbor, weight in graph[min_node].items():
            new_distance = distances[min_node] + weight

            if new_distance < distances[neighbor]:
                distances[neighbor] = new_distance
                previous[neighbor] = min_node

    return distances, previous

def print_path(previous, start, node):
        path = []
        current = node

        while current is not None:
            path.append(current)
            current = previous[current]

        path.reverse()

        print(f"{start} → {node} path:", " -> ".join(path))

start = input("Enter source node: ")

distances, previous = dijkstra_with_path(graph, start)

print("\nShortest Paths and Distances:\n")

for node in graph:
    print_path(previous, start, node)
    print(f"Total distance = {distances[node]}\n")
# Out:
# Enter source node: A
#
# Shortest Paths and Distances:
#
# A → A path: A
# Total distance = 0
#
# A → B path: A -> B
# Total distance = 4
#
# A → C path: A -> C
# Total distance = 2

# %%
# Adding two new nodes E and F

graph['E'] = {}
graph['F'] = {}

# %%
graph['E']['D'] = 2
graph['E']['F'] = 3

graph['F']['E'] = 3

# %%
graph['D']['E'] = 2
graph['E']['D'] = 2
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_17490/1677442110.py in <cell line: 0>()
# ----> 1 graph['D']['E'] = 2
#       2 graph['E']['D'] = 2
#
# KeyError: 'D'
